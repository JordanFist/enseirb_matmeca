# %% [markdown]
# # TD 1.1 : un réseau (singleton) de neurone(s)
#
# Dans ce TD nous allons toucher à Kéras mais de manière douce. Nous ne verrons qu'un réseau de neurones limité à un seul neurone. Avec en plus une fonction d'activation linéaire.
#
# Bref, nous allons étudier la fonction $y=w.x+b$, tout simplement, où $w$ est le poids du neurone.
#
# L'objet de ce TD est de comprendre ce que fait la fonction `fit` de Keras et de démystifier le machine learning.

# %% [markdown]
# ## 1 Création d'un jeu de données
#
# Il faut d'abord créer les données et importer toutes les librairies. Vous allez donc voir les données que nous voulons apprende. Il s'agit pour l'instant simplement de la fonction linéaire $y=7.x + 3$
#
# Attention, prenez le temps de bien comprendre les dimensions des objets manipulés. Il peut s'agir pour vous de manipuler pour la première fois des matrices de Numpy.

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
from keras.callbacks import Callback


import numpy as np

NBPOINTS = 100
# generate data
datax = np.array([(x / 100 + 1) for x in range(0, NBPOINTS)]).reshape(-1,1)
datay = 7 * datax + 3  # This applies on all the elements of the vector

# We add some noise to the perfect line
datay += np.random.normal(0, 0.05, NBPOINTS).reshape(100,1)

# We have a vector of inputs as x (the "data")... e.g. a vector of vectors (each input is a vector)
# We have a vector of outputs as y (the "function to learn") e.g. a vector of vectors of output (each output is also a vector of number)
print("shape of datax's :", datax.shape)
print("shape of datay's :", datay.shape)
plt.plot(datax, datay)
plt.title("Points to approximate")
plt.xlabel("X (data)"); plt.ylabel("Y (real values)")
# Out:
# shape of datax's : (100, 1)
# shape of datay's : (100, 1)
# Text(0, 0.5, 'Y (real values)')

# %% [markdown]
# ## 2 Préparation du modèle en Keras
#
# L'apprentissage peut se faire exemple après exemple, mais également par groupe d'exemples (des batchs). L'avantage de l'utilisation de batch est multiple : cela permet par exemple de trouver immédiatement comment faire évoluer le réseau de neurones pour un ensemble de points. Cela permet également de jouer sur la performance des CPU et des GPU à paralleliser du code concernant des opérations matricielles. En interne, cela ajoute une dimension à toutes les opérations : le réseau apprend en même temps avec plusieurs exemples à la fois.
#
# Pour comprendre ce qui se fait en interne, nous allons utiliser une fonction `callback` qui sera appelée après chaque traitement de `Batch` et chaque find d'`Epoch`. La class `History`, dans la suite, permet de mémoriser tous les paramètres actuels du modèle qui est en train d'apprendre. Cela nous permettra de rejouer tout l'apprentissage plus tard.
#
# ** Vous devez passer un peu de temps sur les documentations Keras **
#
# - Remplissez la méthode `linear_model()` de manière à renvoyer un réseau de neurones ayant un seul neurone.
# - Utilisez la méthode `compile(...)` de Kéras pour préparer le réseau de neurones
#     - L'activation doit être linéaire
#     - Vous devez spécifier la valeur de `input_dim`
#     - Ajoutez l'initialisation aléatoire des poids dans le réseau
#
# - La fonction `getwb(layer)` permet de récupérer les valeurs des poids et biais d'une couche de neurones. Dans notre cas, cela permet de retourner `w` et `b` dans l'équation `y=w.x+b`

# %%
MAXEPOCHS = 100
cmap = matplotlib.cm.get_cmap('magma')

def getwb(layer):
    [tmpw, tmpb] = layer.get_weights()
    return (tmpw[0][0], tmpb[0])

# Function that will be called after each epoch
# I use this function to memorize everything that happened during learning
class History(Callback):
    def __init__(self):
        self.history = {}
        self.batchHistory = []
    def addkeyvalue(self, k, v):
        if not k in self.history: self.history[k] = []
        self.history[k].append(v)
    def on_epoch_end(self, epoch, logs={}):                                                                                 
        for k,v in logs.items():
            self.addkeyvalue(k,v)
        # Here, we gets the values of the unique neuron: its weights and its bias
        (w,b) = getwb(self.model)
        self.addkeyvalue('w',w); self.addkeyvalue('b',b)
        print(w, b)
        print(".",end="")
    def on_batch_end(self, batch, logs={}):
        self.batchHistory.append(getwb(self.model))
        
       
#Define the model: Just one neuron!!
def linear_model():
    model = Sequential()
    # 1 -> nombre de neuronne
    # kernel_initializer = 'random_uniform' -> initialisation aléatoire des poids dans le réseau 
    model.add(Dense(1, input_dim = 1, kernel_initializer = 'random_uniform', activation = 'linear'))
    model.summary()
    #lr -> learning rate (à quel point à chaque epoch il peut faire varier ses parametres dans la descente de gradient, plus il est grand plus on converge vite mais plus on a du mal a se rapprocher du resultat precisement)
    model.compile(loss = 'mean_squared_error', optimizer = optimizers.RMSprop(lr = 0.1), metrics = ['mae'])
    
    return model

print("Model defined")
# Out:
# Model defined

# %% [markdown]
# ## 3 Utilisation de la méthode `fit`
#
# Utilisez la méthode `fit` pour lancer l'apprentissage.
# - Utilisez la constante MAXEPOCHS pour limiter le nombre d'epochs de l'apprentissage
# - Utilisez un `batch_size` de 1
# - Précisez bien la fonction callback `callbacks=history`

# %%
# Cell that do the learning

model = linear_model()

history = [History()]

print("Values of the neuron before learning :", getwb(model))

#batch_size
model.fit(x = datax, y = datay, batch_size = 1, callbacks = history, epochs = MAXEPOCHS, validation_split = 0.33, verbose = 1)

print("Values of the neuron after learning :", getwb(model))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_11 (Dense)             (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# Values of the neuron before learning : (-0.030975318, 0.0)
# Train on 67 samples, validate on 33 samples
# Epoch 1/100
# 67/67 [==============================] - 0s 4ms/step - loss: 33.8572 - mean_absolute_error: 4.7249 - val_loss: 1.5539 - val_mean_absolute_error: 1.2322
# 5.1037316 5.2455897
# .Epoch 2/100
# 67/67 [==============================] - 0s 978us/step - loss: 0.1564 - mean_absolute_error: 0.3343 - val_loss: 0.6339 - val_mean_absolute_error: 0.7809
# 5.468334 5.029681
# .Epoch 3/100
# 67/67 [==============================] - 0s 973us/step - loss: 0.1166 - mean_absolute_error: 0.2824 - val_loss: 0.2920 - val_mean_absolute_error: 0.5255
# 5.791705 4.6933336
# .Epoch 4/100
# 67/67 [==============================] - 0s 972us/step - loss: 0.0815 - mean_absolute_error: 0.2342 - val_loss: 0.2445 - val_mean_absolute_error: 0.4832
# 6.033 4.293992
# .Epoch 5/100
# 67/67 [==============================] - 0s 971us/step - loss: 0.0532 - mean_absolute_error: 0.1884 - val_loss: 0.4354 - val_mean_absolute_error: 0.6533
# 6.1753936 3.8633025
# .Epoch 6/100
# 67/67 [==============================] - 0s 975us/step - loss: 0.0345 - mean_absolute_error: 0.1522 - val_loss: 0.0570 - val_mean_absolute_error: 0.2289
# 6.484504 3.722098
# .Epoch 7/100
# 67/67 [==============================] - 0s 980us/step - loss: 0.0330 - mean_absolute_error: 0.1515 - val_loss: 0.0266 - val_mean_absolute_error: 0.1532
# 6.664363 3.4686449
# .Epoch 8/100
# 67/67 [==============================] - 0s 970us/step - loss: 0.0267 - mean_absolute_error: 0.1303 - val_loss: 0.0235 - val_mean_absolute_error: 0.1463
# 6.8925123 3.3506017
# .Epoch 9/100
# 67/67 [==============================] - 0s 988us/step - loss: 0.0181 - mean_absolute_error: 0.1057 - val_loss: 0.0205 - val_mean_absolute_error: 0.1353
# 6.8440585 3.1577058
# .Epoch 10/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0178 - mean_absolute_error: 0.1030 - val_loss: 0.0199 - val_mean_absolute_error: 0.1332
# 6.8873224 3.0806158
# .Epoch 11/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0183 - mean_absolute_error: 0.1095 - val_loss: 0.0855 - val_mean_absolute_error: 0.2885
# 6.839078 3.0136292
# .Epoch 12/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0169 - mean_absolute_error: 0.1043 - val_loss: 0.0024 - val_mean_absolute_error: 0.0385
# 6.971712 3.0374317
# .Epoch 13/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0136 - mean_absolute_error: 0.0850 - val_loss: 0.0022 - val_mean_absolute_error: 0.0367
# 6.9493146 3.0867372
# .Epoch 14/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0163 - mean_absolute_error: 0.1024 - val_loss: 0.0430 - val_mean_absolute_error: 0.2026
# 7.0608916 3.098735
# .Epoch 15/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0147 - mean_absolute_error: 0.0951 - val_loss: 0.0209 - val_mean_absolute_error: 0.1374
# 6.920618 3.0154867
# .Epoch 16/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0192 - mean_absolute_error: 0.1129 - val_loss: 0.0456 - val_mean_absolute_error: 0.2086
# 6.9094477 2.9647663
# .Epoch 17/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0185 - mean_absolute_error: 0.1100 - val_loss: 0.0500 - val_mean_absolute_error: 0.2191
# 6.9236054 2.9283085
# .Epoch 18/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0174 - mean_absolute_error: 0.1132 - val_loss: 0.0239 - val_mean_absolute_error: 0.1481
# 6.9638534 2.9256456
# .Epoch 19/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0159 - mean_absolute_error: 0.0947 - val_loss: 0.0067 - val_mean_absolute_error: 0.0711
# 7.0027356 2.9336395
# .Epoch 20/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0172 - mean_absolute_error: 0.1096 - val_loss: 0.0932 - val_mean_absolute_error: 0.3019
# 7.1521244 3.031162
# .Epoch 21/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0183 - mean_absolute_error: 0.1080 - val_loss: 0.0088 - val_mean_absolute_error: 0.0827
# 7.134202 2.844477
# .Epoch 22/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0178 - mean_absolute_error: 0.1074 - val_loss: 0.0116 - val_mean_absolute_error: 0.0979
# 7.1148505 2.8953154
# .Epoch 23/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0191 - mean_absolute_error: 0.1097 - val_loss: 0.0039 - val_mean_absolute_error: 0.0517
# 7.085286 2.8962479
# .Epoch 24/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0166 - mean_absolute_error: 0.1047 - val_loss: 0.0484 - val_mean_absolute_error: 0.2156
# 6.9710903 2.8449566
# .Epoch 25/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0180 - mean_absolute_error: 0.1036 - val_loss: 0.0588 - val_mean_absolute_error: 0.2384
# 6.94105 2.877094
# .Epoch 26/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0168 - mean_absolute_error: 0.1038 - val_loss: 0.0193 - val_mean_absolute_error: 0.1316
# 6.962783 2.9441094
# .Epoch 27/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0163 - mean_absolute_error: 0.1053 - val_loss: 0.0413 - val_mean_absolute_error: 0.1982
# 6.9427557 2.914165
# .Epoch 28/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0171 - mean_absolute_error: 0.0982 - val_loss: 0.0103 - val_mean_absolute_error: 0.0921
# 7.016053 2.8868647
# .Epoch 29/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0158 - mean_absolute_error: 0.1035 - val_loss: 0.0098 - val_mean_absolute_error: 0.0891
# 7.0697227 2.9687774
# .Epoch 30/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0147 - mean_absolute_error: 0.0954 - val_loss: 0.1340 - val_mean_absolute_error: 0.3632
# 7.170618 3.0585978
# .Epoch 31/100
# 67/67 [==============================] - 0s 986us/step - loss: 0.0151 - mean_absolute_error: 0.0985 - val_loss: 0.0222 - val_mean_absolute_error: 0.1421
# 7.1178193 2.9340873
# .Epoch 32/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0165 - mean_absolute_error: 0.1092 - val_loss: 0.0021 - val_mean_absolute_error: 0.0400
# 7.090794 2.8555164
# .Epoch 33/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0160 - mean_absolute_error: 0.1049 - val_loss: 0.0327 - val_mean_absolute_error: 0.1754
# 7.030524 2.7763417
# .Epoch 34/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0161 - mean_absolute_error: 0.0994 - val_loss: 0.0215 - val_mean_absolute_error: 0.1396
# 7.1473184 2.8776398
# .Epoch 35/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0162 - mean_absolute_error: 0.1074 - val_loss: 0.0292 - val_mean_absolute_error: 0.1649
# 7.1193647 2.9541101
# .Epoch 36/100
# 67/67 [==============================] - 0s 989us/step - loss: 0.0163 - mean_absolute_error: 0.1003 - val_loss: 0.0052 - val_mean_absolute_error: 0.0599
# 7.0864773 2.791994
# .Epoch 37/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0179 - mean_absolute_error: 0.1012 - val_loss: 0.0451 - val_mean_absolute_error: 0.2073
# 7.171693 2.9006796
# .Epoch 38/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0180 - mean_absolute_error: 0.1095 - val_loss: 0.0213 - val_mean_absolute_error: 0.1388
# 7.1301208 2.9083233
# .Epoch 39/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0168 - mean_absolute_error: 0.1034 - val_loss: 0.0853 - val_mean_absolute_error: 0.2883
# 7.177041 2.971965
# .Epoch 40/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0159 - mean_absolute_error: 0.0948 - val_loss: 0.0233 - val_mean_absolute_error: 0.1461
# 6.985124 2.8887208
# .Epoch 41/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0194 - mean_absolute_error: 0.1118 - val_loss: 0.0133 - val_mean_absolute_error: 0.1065
# 7.066654 2.9921098
# .Epoch 42/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0165 - mean_absolute_error: 0.0973 - val_loss: 0.0084 - val_mean_absolute_error: 0.0823
# 6.951274 3.016359
# .Epoch 43/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0164 - mean_absolute_error: 0.0997 - val_loss: 0.0032 - val_mean_absolute_error: 0.0464
# 6.9796085 3.0803354
# .Epoch 44/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0167 - mean_absolute_error: 0.0997 - val_loss: 0.0130 - val_mean_absolute_error: 0.1051
# 7.006959 2.889758
# .Epoch 45/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0156 - mean_absolute_error: 0.0996 - val_loss: 0.0169 - val_mean_absolute_error: 0.1220
# 6.969147 2.9420183
# .Epoch 46/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0199 - mean_absolute_error: 0.1113 - val_loss: 0.0099 - val_mean_absolute_error: 0.0894
# 7.0715 2.9658935
# .Epoch 47/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0164 - mean_absolute_error: 0.1022 - val_loss: 0.0244 - val_mean_absolute_error: 0.1499
# 6.9698043 2.9129632
# .Epoch 48/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0177 - mean_absolute_error: 0.1134 - val_loss: 0.0388 - val_mean_absolute_error: 0.1920
# 6.998644 2.8181164
# .Epoch 49/100
# 67/67 [==============================] - 0s 993us/step - loss: 0.0178 - mean_absolute_error: 0.1094 - val_loss: 0.0526 - val_mean_absolute_error: 0.2251
# 7.0928698 3.0627673
# .Epoch 50/100
# 67/67 [==============================] - 0s 992us/step - loss: 0.0146 - mean_absolute_error: 0.0992 - val_loss: 0.0198 - val_mean_absolute_error: 0.1337
# 7.014831 3.1141584
# .Epoch 51/100
# 67/67 [==============================] - 0s 963us/step - loss: 0.0153 - mean_absolute_error: 0.1042 - val_loss: 0.0056 - val_mean_absolute_error: 0.0633
# 6.982797 2.978682
# .Epoch 52/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0179 - mean_absolute_error: 0.1038 - val_loss: 0.0142 - val_mean_absolute_error: 0.1105
# 7.081889 2.9682426
# .Epoch 53/100
# 67/67 [==============================] - 0s 995us/step - loss: 0.0170 - mean_absolute_error: 0.1080 - val_loss: 0.0666 - val_mean_absolute_error: 0.2541
# 7.15141 2.9846678
# .Epoch 54/100
# 67/67 [==============================] - 0s 962us/step - loss: 0.0179 - mean_absolute_error: 0.1039 - val_loss: 0.0059 - val_mean_absolute_error: 0.0652
# 6.9956675 2.9529347
# .Epoch 55/100
# 67/67 [==============================] - 0s 992us/step - loss: 0.0140 - mean_absolute_error: 0.0917 - val_loss: 0.0849 - val_mean_absolute_error: 0.2877
# 6.8596888 2.9767237
# .Epoch 56/100
# 67/67 [==============================] - 0s 960us/step - loss: 0.0172 - mean_absolute_error: 0.1001 - val_loss: 0.0273 - val_mean_absolute_error: 0.1590
# 6.9166718 3.00105
# .Epoch 57/100
# 67/67 [==============================] - 0s 989us/step - loss: 0.0163 - mean_absolute_error: 0.1043 - val_loss: 0.0208 - val_mean_absolute_error: 0.1373
# 7.0262985 3.096825
# .Epoch 58/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0187 - mean_absolute_error: 0.1024 - val_loss: 0.0023 - val_mean_absolute_error: 0.0400
# 7.0008783 3.024877
# .Epoch 59/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0147 - mean_absolute_error: 0.0954 - val_loss: 0.0490 - val_mean_absolute_error: 0.2165
# 6.8921833 2.9883952
# .Epoch 60/100
# 67/67 [==============================] - 0s 960us/step - loss: 0.0168 - mean_absolute_error: 0.1021 - val_loss: 0.0058 - val_mean_absolute_error: 0.0650
# 6.963562 3.136095
# .Epoch 61/100
# 67/67 [==============================] - 0s 984us/step - loss: 0.0161 - mean_absolute_error: 0.1095 - val_loss: 0.0023 - val_mean_absolute_error: 0.0395
# 6.9436655 3.1280882
# .Epoch 62/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0187 - mean_absolute_error: 0.1135 - val_loss: 0.0198 - val_mean_absolute_error: 0.1338
# 7.017119 3.1101265
# .Epoch 63/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0146 - mean_absolute_error: 0.0996 - val_loss: 0.0490 - val_mean_absolute_error: 0.2167
# 6.916542 2.9435892
# .Epoch 64/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0191 - mean_absolute_error: 0.1154 - val_loss: 0.0059 - val_mean_absolute_error: 0.0654
# 7.012321 2.922086
# .Epoch 65/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0154 - mean_absolute_error: 0.0969 - val_loss: 0.0224 - val_mean_absolute_error: 0.1431
# 6.985097 2.891809
# .Epoch 66/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0173 - mean_absolute_error: 0.1006 - val_loss: 0.0126 - val_mean_absolute_error: 0.1033
# 7.029144 3.0575895
# .Epoch 67/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0147 - mean_absolute_error: 0.0946 - val_loss: 0.0092 - val_mean_absolute_error: 0.0864
# 6.9867706 2.9466922
# .Epoch 68/100
# 67/67 [==============================] - 0s 969us/step - loss: 0.0176 - mean_absolute_error: 0.1009 - val_loss: 0.0233 - val_mean_absolute_error: 0.1464
# 7.033471 3.0927234
# .Epoch 69/100
# 67/67 [==============================] - 0s 974us/step - loss: 0.0157 - mean_absolute_error: 0.0994 - val_loss: 0.0155 - val_mean_absolute_error: 0.1165
# 6.996844 3.129903
# .Epoch 70/100
# 67/67 [==============================] - 0s 968us/step - loss: 0.0133 - mean_absolute_error: 0.0954 - val_loss: 0.0607 - val_mean_absolute_error: 0.2423
# 6.9343424 2.8854148
# .Epoch 71/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0166 - mean_absolute_error: 0.1047 - val_loss: 0.0246 - val_mean_absolute_error: 0.1506
# 7.086705 2.9995136
# .Epoch 72/100
# 67/67 [==============================] - 0s 978us/step - loss: 0.0157 - mean_absolute_error: 0.0997 - val_loss: 0.0059 - val_mean_absolute_error: 0.0651
# 7.048436 2.8560104
# .Epoch 73/100
# 67/67 [==============================] - 0s 976us/step - loss: 0.0134 - mean_absolute_error: 0.0943 - val_loss: 0.0036 - val_mean_absolute_error: 0.0488
# 7.040891 2.9735012
# .Epoch 74/100
# 67/67 [==============================] - 0s 991us/step - loss: 0.0139 - mean_absolute_error: 0.0942 - val_loss: 0.1214 - val_mean_absolute_error: 0.3455
# 6.919878 2.808684
# .Epoch 75/100
# 67/67 [==============================] - 0s 971us/step - loss: 0.0188 - mean_absolute_error: 0.1086 - val_loss: 0.0031 - val_mean_absolute_error: 0.0429
# 6.9622474 3.043543
# .Epoch 76/100
# 67/67 [==============================] - 0s 980us/step - loss: 0.0164 - mean_absolute_error: 0.0955 - val_loss: 0.0322 - val_mean_absolute_error: 0.1741
# 7.0133605 3.1572804
# .Epoch 77/100
# 67/67 [==============================] - 0s 976us/step - loss: 0.0178 - mean_absolute_error: 0.1128 - val_loss: 0.0125 - val_mean_absolute_error: 0.1029
# 6.9928236 3.1234035
# .Epoch 78/100
# 67/67 [==============================] - 0s 1ms/step - loss: 0.0143 - mean_absolute_error: 0.0909 - val_loss: 0.0148 - val_mean_absolute_error: 0.1135
# 7.0503654 3.0289352
# .Epoch 79/100
# 67/67 [==============================] - 0s 987us/step - loss: 0.0178 - mean_absolute_error: 0.1128 - val_loss: 0.0022 - val_mean_absolute_error: 0.0377
# 7.0151324 2.9630215
# .Epoch 80/100
# 67/67 [==============================] - 0s 973us/step - loss: 0.0179 - mean_absolute_error: 0.1097 - val_loss: 0.0042 - val_mean_absolute_error: 0.0519
# 7.003606 2.9535453
# .Epoch 81/100
# 67/67 [==============================] - 0s 966us/step - loss: 0.0152 - mean_absolute_error: 0.1009 - val_loss: 0.0328 - val_mean_absolute_error: 0.1757
# 7.0655284 3.063413
# .Epoch 82/100
# 67/67 [==============================] - 0s 990us/step - loss: 0.0200 - mean_absolute_error: 0.1144 - val_loss: 0.0039 - val_mean_absolute_error: 0.0512
# 7.055524 2.950454
# .Epoch 83/100
# 67/67 [==============================] - 0s 973us/step - loss: 0.0158 - mean_absolute_error: 0.0962 - val_loss: 0.0310 - val_mean_absolute_error: 0.1705
# 6.979083 2.8753932
# .Epoch 84/100
# 67/67 [==============================] - 0s 979us/step - loss: 0.0149 - mean_absolute_error: 0.1031 - val_loss: 0.0729 - val_mean_absolute_error: 0.2663
# 7.1411405 3.0155745
# .Epoch 85/100
# 67/67 [==============================] - 0s 981us/step - loss: 0.0171 - mean_absolute_error: 0.1011 - val_loss: 0.0106 - val_mean_absolute_error: 0.0938
# 7.0387554 2.843259
# .Epoch 86/100
# 67/67 [==============================] - 0s 980us/step - loss: 0.0147 - mean_absolute_error: 0.1016 - val_loss: 0.0025 - val_mean_absolute_error: 0.0419
# 7.0158587 3.0028703
# .Epoch 87/100
# 67/67 [==============================] - 0s 984us/step - loss: 0.0176 - mean_absolute_error: 0.1077 - val_loss: 0.0025 - val_mean_absolute_error: 0.0415
# 7.007823 3.0165155
# .Epoch 88/100
# 67/67 [==============================] - 0s 979us/step - loss: 0.0157 - mean_absolute_error: 0.0982 - val_loss: 0.0066 - val_mean_absolute_error: 0.0705
# 7.040548 3.0016708
# .Epoch 89/100
# 67/67 [==============================] - 0s 982us/step - loss: 0.0144 - mean_absolute_error: 0.0909 - val_loss: 0.0053 - val_mean_absolute_error: 0.0613
# 7.0487094 2.9762983
# .Epoch 90/100
# 67/67 [==============================] - 0s 984us/step - loss: 0.0167 - mean_absolute_error: 0.1139 - val_loss: 0.0055 - val_mean_absolute_error: 0.0631
# 7.062173 2.9538248
# .Epoch 91/100
# 67/67 [==============================] - 0s 999us/step - loss: 0.0144 - mean_absolute_error: 0.1032 - val_loss: 0.0320 - val_mean_absolute_error: 0.1732
# 6.9389358 2.946143
# .Epoch 92/100
# 67/67 [==============================] - 0s 979us/step - loss: 0.0182 - mean_absolute_error: 0.1107 - val_loss: 0.0200 - val_mean_absolute_error: 0.1343
# 6.9424305 2.9786203
# .Epoch 93/100
# 67/67 [==============================] - 0s 978us/step - loss: 0.0153 - mean_absolute_error: 0.1019 - val_loss: 0.0993 - val_mean_absolute_error: 0.3118
# 6.8927345 2.892123
# .Epoch 94/100
# 67/67 [==============================] - 0s 980us/step - loss: 0.0231 - mean_absolute_error: 0.1194 - val_loss: 0.0040 - val_mean_absolute_error: 0.0503
# 7.0054708 2.9523063
# .Epoch 95/100
# 67/67 [==============================] - 0s 976us/step - loss: 0.0148 - mean_absolute_error: 0.0894 - val_loss: 0.0032 - val_mean_absolute_error: 0.0436
# 7.01844 2.9386847
# .Epoch 96/100
# 67/67 [==============================] - 0s 982us/step - loss: 0.0172 - mean_absolute_error: 0.1027 - val_loss: 0.0467 - val_mean_absolute_error: 0.2114
# 7.1078234 3.0216806
# .Epoch 97/100
# 67/67 [==============================] - 0s 985us/step - loss: 0.0166 - mean_absolute_error: 0.1057 - val_loss: 0.0166 - val_mean_absolute_error: 0.1208
# 6.9649577 2.9508972
# .Epoch 98/100
# 67/67 [==============================] - 0s 985us/step - loss: 0.0175 - mean_absolute_error: 0.1058 - val_loss: 0.0068 - val_mean_absolute_error: 0.0718
# 7.031598 3.019497
# .Epoch 99/100
# 67/67 [==============================] - 0s 986us/step - loss: 0.0176 - mean_absolute_error: 0.1025 - val_loss: 0.0041 - val_mean_absolute_error: 0.0507
# 6.9317427 3.086804
# .Epoch 100/100
# 67/67 [==============================] - 0s 985us/step - loss: 0.0170 - mean_absolute_error: 0.1139 - val_loss: 0.0115 - val_mean_absolute_error: 0.0979
# 7.0394645 3.0331945
# .Values of the neuron after learning : (7.0394645, 3.0331945)

# %% [markdown]
# ## 4 Essayez différentes techniques
#
# Utilisez toutes les cellules ci-dessous pour visualiser comment le réseau converge et apprend.
# - Notez à quelle vitesse les valeurs `w` et `b` convergent vite
# - Notez également à quel moment les valeurs se stabilisent
#
# **Différentes techniques à essayer**
# - quel impact a le *learning rate* (essayez `0.1, 0.3, 0.05, ...`) sur les figures ci-dessous ?
# - quel impact a le *batch_size* sur le temps et les figures ?
# - changez la heatmap pour afficher seulement le log du loss plutot que le loss

# %%
n = 0
plt.figure(n); n+=1
plt.title("Evolution of the learnt curve")
plt.xlabel("x")
plt.xlabel("y")
wtmp = history[0].history['w']
btmp = history[0].history['b']
for i, w in enumerate(wtmp):
    out = datax * w + btmp[i] # Gives what the model predicted for all outputs at epoch i
    # in fact this is exactly what model.predict(datax) would have given us after this epoch
    plt.plot(datax, out, color=cmap(i/MAXEPOCHS))
plt.plot(datax,datay,'k') # Plots the initial data
 
#Use the model


plt.figure(n); n+=1
plt.title("Mean Absolute Error")
plt.xlabel("#Epoch")
plt.plot(history[0].history['mean_absolute_error'])

plt.figure(n); n+=1
plt.title("Loss")
plt.xlabel("#Epoch")
plt.plot(history[0].history['loss'])
plt.plot(history[0].history['val_loss'])

plt.figure(n); n+=1
plt.title("learnt w in y = w.x + b")
plt.xlabel("#Epoch")
plt.plot(history[0].history['w'])

plt.figure(n); n+=1
plt.title("learnt b in y = w.x + b")
plt.xlabel("#Epoch")
plt.plot(history[0].history['b'])

# %% [markdown]
# #### Affichage simple de l'équation apprise

# %%
[w,a] = model.get_weights()
print("y={}.x + {}".format(w[0][0], a[0]))
# Out:
# y=6.950859546661377.x + 2.8347408771514893

# %% [markdown]
# ### Construction des valeurs de la heatmap

# %%
ws = (min(history[0].history['w'])-1, max(history[0].history['w'])+1)
print("Values of w's are inside {}".format(ws))
bs = (min(history[0].history['b'])-1, max(history[0].history['b'])+1)
print("Values of b's are inside {}".format(bs))

# Very simple loss computation... Can be done with numpy much more efficiently
def getloss(X, Y, w, b):
    totalLoss = 0
    for i, x in enumerate(X):
        xx = x[0]
        my = xx * w + b
        loss = abs(my-Y[i][0])
        loss *= loss
        totalLoss += loss
    return totalLoss / len(X)

RESOLUTION = 100 # The map will be 100x100
hmap = np.zeros((RESOLUTION,RESOLUTION))
xticks = np.linspace(ws[0], ws[1], RESOLUTION, endpoint=False)
yticks = np.linspace(bs[0], bs[1], RESOLUTION, endpoint=False)
xi = 0
for xx in xticks:
    yi = 0
    for yy in yticks:
        hmap[yi, xi] = getloss(datax, datay, xx, yy)
        yi += 1
    xi += 1
getloss(datax,datay,7,3)
# Out:
# Values of w's are inside (0.32558202743530273, 8.142423152923584)
# Values of b's are inside (0.2929941415786743, 6.229707717895508)
# 0.002414297578751726

# %% [markdown]
# ### Affichage de la HeapMap du loss
#
# Cette partie permet de voir l'évolution des valeurs `w` et `b` au cours de l'apprentissage, en représentant les valeurs après chaque *batch* et/ou après chaque *epoch*

# %%
# Getting a picture of the moves of the search
fig, ax = plt.subplots()

minz = hmap.min()
maxz = hmap.max()
c = ax.pcolormesh(xticks, yticks, hmap, cmap='hsv', vmin=minz, vmax=maxz)
ax.set_title('Loss')
plt.xlabel('w\'s values')
plt.ylabel('b\'s values')
# set the limits of the plot to the limits of the data
ax.axis([ws[0], ws[1], bs[0], bs[1]])
fig.colorbar(c, ax=ax)
plt.plot([x[0] for x in history[0].batchHistory], [x[1] for x in history[0].batchHistory], color='gray')
plt.plot([xx for xx in history[0].history['w']], [xx for xx in history[0].history['b']], color='black')
plt.legend(['Weights after each batch', 'Weights after each epoch'])
plt.show()

# %% [markdown]
# ## 4 refaire tout l'apprentissage sans keras
#
# Comment reprendre tout directement en python, depuis `datax`et `datay` pour simuler exactement ce que fait la méthode `fit` en passant chaque exemple, calculer le `loss` et mettre à jour `w` et `b` en respectant le learning rate donné. Vous spécialiserez votre méthode pour apprendre uniquement les fonctions `y=w.x+b` sans forcément viser des résultats génériques.
